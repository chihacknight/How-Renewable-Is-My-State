# %%
import pandas as pd
#pandas is an awesome library for python, lets you do lots of stuff you might otherwise do in R

# %%
#create a pandas dataframe by reading in the csv form the remote site(in a single line of code <#)
df = pd.read_csv('http://www.eia.gov/state/seds/CDF/Complete_SEDS.csv')

# %%
df
# Out:
#         Data_Status    MSN StateCode  Year  Data
# 0             2014F  ABICB        AK  1960   0.0
# 1             2014F  ABICB        AK  1961   0.0
# 2             2014F  ABICB        AK  1962   0.0
# 3             2014F  ABICB        AK  1963   0.0
# 4             2014F  ABICB        AK  1964   0.0
# 5             2014F  ABICB        AK  1965   0.0
# 6             2014F  ABICB        AK  1966   0.0
# 7             2014F  ABICB        AK  1967   0.0
# 8             2014F  ABICB        AK  1968   0.0
# 9             2014F  ABICB        AK  1969   0.0
# 10            2014F  ABICB        AK  1970   0.0
# 11            2014F  ABICB        AK  1971   0.0
# 12            2014F  ABICB        AK  1972   0.0
# 13            2014F  ABICB        AK  1973   0.0
# 14            2014F  ABICB        AK  1974   0.0
# 15            2014F  ABICB        AK  1975   0.0
# 16            2014F  ABICB        AK  1976   0.0
# 17            2014F  ABICB        AK  1977   0.0
# 18            2014F  ABICB        AK  1978   0.0
# 19            2014F  ABICB        AK  1979   0.0
# 20            2014F  ABICB        AK  1980   0.0
# 21            2014F  ABICB        AK  1981  42.0
# 22            2014F  ABICB        AK  1982  45.0
# 23            2014F  ABICB        AK  1983   6.0
# 24            2014F  ABICB        AK  1984   1.0
# 25            2014F  ABICB        AK  1985  50.0
# 26            2014F  ABICB        AK  1986   8.0
# 27            2014F  ABICB        AK  1987   1.0
# 28            2014F  ABICB        AK  1988 -15.0
# 29            2014F  ABICB        AK  1989   2.0
# ...             ...    ...       ...   ...   ...
# 1556033       2014F  WYTXP        WY  1985   0.0
# 1556034       2014F  WYTXP        WY  1986   0.0
# 1556035       2014F  WYTXP        WY  1987   0.0
# 1556036       2014F  WYTXP        WY  1988   0.0
# 1556037       2014F  WYTXP        WY  1989   0.0
# 1556038       2014F  WYTXP        WY  1990   0.0
# 1556039       2014F  WYTXP        WY  1991   0.0
# 1556040       2014F  WYTXP        WY  1992   0.0
# 1556041       2014F  WYTXP        WY  1993   0.0
# 1556042       2014F  WYTXP        WY  1994   0.0
# 1556043       2014F  WYTXP        WY  1995   0.0
# 1556044       2014F  WYTXP        WY  1996   0.0
# 1556045       2014F  WYTXP        WY  1997   0.0
# 1556046       2014F  WYTXP        WY  1998   0.0
# 1556047       2014F  WYTXP        WY  1999   0.0
# 1556048       2014F  WYTXP        WY  2000   0.0
# 1556049       2014F  WYTXP        WY  2001   0.0
# 1556050       2014F  WYTXP        WY  2002   0.0
# 1556051       2014F  WYTXP        WY  2003   0.0
# 1556052       2014F  WYTXP        WY  2004   0.0
# 1556053       2014F  WYTXP        WY  2005   0.0
# 1556054       2014F  WYTXP        WY  2006   0.0
# 1556055       2014F  WYTXP        WY  2007   0.0
# 1556056       2014F  WYTXP        WY  2008   0.0
# 1556057       2014F  WYTXP        WY  2009   0.0
# 1556058       2014F  WYTXP        WY  2010   0.0
# 1556059       2014F  WYTXP        WY  2011   0.0
# 1556060       2014F  WYTXP        WY  2012   0.0
# 1556061       2014F  WYTXP        WY  2013   0.0
# 1556062       2014F  WYTXP        WY  2014   0.0
#
# [1556063 rows x 5 columns]

# %%
#we only want some of the values in the raw data, we can filter to help keep the size of our DB down
values_list = [
    "TETCB",
    "FFTCB",
    "CLTCB",
    "NNTCB",
    "PMTCB",
    "NUETB",
    "RETCB",
    "EMLCB",
    "EMTCB",
    "GETCB",
    "HYTCB",
    "SOTCB",
    "WWTCB",
    "WYTCB",
    "ELNIB",
    "ELISB" 
]
#make a new dataframe that is a filtered version of the original
filtered_df = df[df['MSN'].isin(values_list)]
#lets also cast the column names to lower case
filtered_df
# Out:
#         Data_Status    MSN StateCode  Year     Data
# 171895        2014F  CLTCB        AK  1960   7189.0
# 171896        2014F  CLTCB        AK  1961  11552.0
# 171897        2014F  CLTCB        AK  1962  13559.0
# 171898        2014F  CLTCB        AK  1963  11999.0
# 171899        2014F  CLTCB        AK  1964  12029.0
# 171900        2014F  CLTCB        AK  1965   9888.0
# 171901        2014F  CLTCB        AK  1966  16431.0
# 171902        2014F  CLTCB        AK  1967  18462.0
# 171903        2014F  CLTCB        AK  1968  15998.0
# 171904        2014F  CLTCB        AK  1969  13191.0
# 171905        2014F  CLTCB        AK  1970  13159.0
# 171906        2014F  CLTCB        AK  1971  14121.0
# 171907        2014F  CLTCB        AK  1972  12753.0
# 171908        2014F  CLTCB        AK  1973  13286.0
# 171909        2014F  CLTCB        AK  1974  12485.0
# 171910        2014F  CLTCB        AK  1975  15271.0
# 171911        2014F  CLTCB        AK  1976  13706.0
# 171912        2014F  CLTCB        AK  1977  10259.0
# 171913        2014F  CLTCB        AK  1978   4689.0
# 171914        2014F  CLTCB        AK  1979   4182.0
# 171915        2014F  CLTCB        AK  1980   4310.0
# 171916        2014F  CLTCB        AK  1981  12521.0
# 171917        2014F  CLTCB        AK  1982  13182.0
# 171918        2014F  CLTCB        AK  1983  12403.0
# 171919        2014F  CLTCB        AK  1984  12883.0
# 171920        2014F  CLTCB        AK  1985  11587.0
# 171921        2014F  CLTCB        AK  1986  12150.0
# 171922        2014F  CLTCB        AK  1987   4330.0
# 171923        2014F  CLTCB        AK  1988   4362.0
# 171924        2014F  CLTCB        AK  1989   4719.0
# ...             ...    ...       ...   ...      ...
# 1547453       2014F  WYTCB        WY  1985     30.0
# 1547454       2014F  WYTCB        WY  1986     14.0
# 1547455       2014F  WYTCB        WY  1987     -2.0
# 1547456       2014F  WYTCB        WY  1988     -1.0
# 1547457       2014F  WYTCB        WY  1989      0.0
# 1547458       2014F  WYTCB        WY  1990      0.0
# 1547459       2014F  WYTCB        WY  1991      0.0
# 1547460       2014F  WYTCB        WY  1992      0.0
# 1547461       2014F  WYTCB        WY  1993      0.0
# 1547462       2014F  WYTCB        WY  1994      0.0
# 1547463       2014F  WYTCB        WY  1995      0.0
# 1547464       2014F  WYTCB        WY  1996      0.0
# 1547465       2014F  WYTCB        WY  1997      0.0
# 1547466       2014F  WYTCB        WY  1998     21.0
# 1547467       2014F  WYTCB        WY  1999    114.0
# 1547468       2014F  WYTCB        WY  2000   2509.0
# 1547469       2014F  WYTCB        WY  2001   3773.0
# 1547470       2014F  WYTCB        WY  2002   4551.0
# 1547471       2014F  WYTCB        WY  2003   3711.0
# 1547472       2014F  WYTCB        WY  2004   6175.0
# 1547473       2014F  WYTCB        WY  2005   7172.0
# 1547474       2014F  WYTCB        WY  2006   7529.0
# 1547475       2014F  WYTCB        WY  2007   7461.0
# 1547476       2014F  WYTCB        WY  2008   9485.0
# 1547477       2014F  WYTCB        WY  2009  21728.0
# 1547478       2014F  WYTCB        WY  2010  31676.0
# 1547479       2014F  WYTCB        WY  2011  44809.0
# 1547480       2014F  WYTCB        WY  2012  41576.0
# 1547481       2014F  WYTCB        WY  2013  42298.0
# 1547482       2014F  WYTCB        WY  2014  41899.0
#
# [45760 rows x 5 columns]

# %%
#filtering this data makes the size way more managable
print("Original: ", df.size, "Filtered: ", filtered_df.size)
# Out:
# Original:  7780315 Filtered:  228800

# %%
#write the file to csv for refrence. this file is about 1.5 megs, way smaller than 50 from the original file!
filtered_df.to_csv('./data/filtered_data.csv')

# %%
#couple ways to filter/sort this data
"""
We've got Years, States, and Data Values (MSN+ it's data)
i.e. If the user visits the site and we want them to see an inital nationwide view for the most recent year
"""
#pretty easy to sort, even by multiple values
filtered_df.sort_values(['year', 'statecode', 'msn'])
#filter specific year (can also be a list of values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\erica\Miniconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4443)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4289)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13733)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13687)()
#
# KeyError: 'year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-37b6db0c4d93> in <module>()
#       5 """
#       6 #pretty easy to sort, even by multiple values
# ----> 7 filtered_df.sort_values(['year', 'statecode', 'msn'])
#       8 #filter specific year (can also be a list of values)
#       9
#
# C:\Users\erica\Miniconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3216             keys = []
#    3217             for x in by:
# -> 3218                 k = self.xs(x, axis=other_axis).values
#    3219                 if k.ndim == 2:
#    3220                     raise ValueError('Cannot sort by duplicate column %s' %
#
# C:\Users\erica\Miniconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    1768
#    1769         if axis == 1:
# -> 1770             return self[key]
#    1771
#    1772         self._consolidate_inplace()
#
# C:\Users\erica\Miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\erica\Miniconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\erica\Miniconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\erica\Miniconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3539
#    3540             if not isnull(item):
# -> 3541                 loc = self.items.get_loc(item)
#    3542             else:
#    3543                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\erica\Miniconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4443)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4289)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13733)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13687)()
#
# KeyError: 'year'

# %%
filtered_df[filtered_df['year'].isin([2012, 2013])].sort_values(['year', 'statecode', 'msn'])

# %%
"""some simple examples of rudimentary data exploration"""
#years
print("Years: ", filtered_df.year.unique(), "Total: ", filtered_df.year.unique().size)
#datatypes
print("data_types: ", filtered_df.msn.unique(), "Total: ", filtered_df.msn.unique().size)
